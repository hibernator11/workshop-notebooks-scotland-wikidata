# %% [markdown]
# This is an example of SPARQL Wikidata access.

# %% [markdown]
# First of all, we include all the python packages that are required to run this example. We will use the SPARQL endpoint to query the data.

# %%
from SPARQLWrapper import SPARQLWrapper, JSON, RDFXML, POST

sparql = SPARQLWrapper(
    "https://query.wikidata.org/sparql"
)

sparql.setMethod(POST)
sparql.setReturnFormat(JSON)

# %% [markdown]
# Now, we define the SPARQL query.

# %%
sparql.setQuery("""
SELECT ?s ?sLabel ?idBnF
WHERE {
# ?s wdt:P268 ?idBnF
  SERVICE wikibase:label { bd:serviceParam wikibase:language "en". }
}
limit 10
"""
)

# %% [markdown]
# Finally, we can retrieve the triples as JSON and save it as a file using the following code:

# %%
import json

try:
    ret = sparql.queryAndConvert()
    #print(ret)
    for r in ret["results"]["bindings"]:
        print(r["s"]["value"] + " - " + r["sLabel"]["value"] + " - " + r["idBnF"]["value"])

    json_str = json.dumps(ret)
    with open("bnf.json", "w") as f:
        f.write(json_str)

except Exception as e:
    print(e)
# Out:
# http://www.wikidata.org/entity/Q6536902 - Lewis Morris - 102823056
# http://www.wikidata.org/entity/Q1879452 - Léon-Vivant Moissenet - 10365259b
# http://www.wikidata.org/entity/Q3188979 - Jules de Calvière - 10464738p
# http://www.wikidata.org/entity/Q320725 - Pellegrino Matteucci - 105525765
# http://www.wikidata.org/entity/Q1606206 - Henriette Bissing - 105640963
# http://www.wikidata.org/entity/Q5558181 - Giannantonio Moschini - 10572771d
# http://www.wikidata.org/entity/Q3163985 - Jean-Baptiste Couture - 106501444
# http://www.wikidata.org/entity/Q15969064 - Charles Louis Benjamin Esnault - 106743175
# http://www.wikidata.org/entity/Q6240417 - John Hungerford Pollen - 10709595f
# http://www.wikidata.org/entity/Q59713007 - Marie Adolphe Dufour - 107196085

# %% [markdown]
# And now we can see the JSON content in the file bnf.json
